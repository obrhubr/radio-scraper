# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/wrangled.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                     name  \
# 0           0             0              100% Pure Poison - Windy C
# 1           1             1        24kgoldn - mood (feat. iann dior)
# 2           2             2  ATB feat. Topic & A7S - Your Love (9PM)
# 3           3             3                        Abba - Angel Eyes
# 4           4             4                      Adaolisa - Fineboy
#
#      station                        date           artist              song
# 0        fm4  2021-04-18 08:36:02.340898    100purepoison            windyc
# 1   kronehit  2021-04-18 15:27:01.755826         24kgoldn  moodfeatianndior
# 2        oe3  2021-04-18 14:27:01.311674  atbfeattopica7s       yourlove9pm
# 3  radiowien  2021-04-18 10:36:02.549508             abba         angeleyes
# 4        fm4  2021-04-18 11:39:03.850160         adaolisa           fineboy

# %%
sns.countplot(x=df["station"])
# Out:
# <AxesSubplot:xlabel='station', ylabel='count'>

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df['date'] = df["date"].round('1h')

# %%
df.head()
# Out:
#    Unnamed: 0                                            name    station  \
# 0           0  100% Pure Poison - Windy C | FM4 Sunny Side Up        fm4
# 1           1               24kgoldn - mood (feat. iann dior)   kronehit
# 2           2                               Abba - Angel Eyes  radiowien
# 3           3              Adaolisa - Fineboy | FM4 Hallo FM4        fm4
# 4           4                                   Adele - Hello        oe3
#
#                  date  fm4  kronehit  oe3  radiowien
# 0 2021-04-18 09:00:00    1         0    0          0
# 1 2021-04-18 10:00:00    0         1    0          0
# 2 2021-04-18 11:00:00    0         0    0          1
# 3 2021-04-18 12:00:00    1         0    0          0
# 4 2021-04-18 12:00:00    0         0    1          0

# %%
df = df.join(pd.get_dummies(df["station"]))

# %%
sns.lineplot(x=df["date"], y=df["kronehit"])
# Out:
# <AxesSubplot:xlabel='date', ylabel='kronehit'>
